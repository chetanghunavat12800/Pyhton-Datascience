# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# ## introduction to series
# #### series is the 1d data
# #### series is in the vertical format

# %%
labels=['a','b','c','d']
my_list=[10,20,30,40]
arr=np.array([100,200,300,400])
dic={1:1000,2:2000,3:3000,4:4000}

# now print the series 
print(pd.Series(my_list))
print("\n")
print(pd.Series(arr))
print("\n")


# if we want to add the custom lables 
print(pd.Series(arr,index=labels))

print()
print(pd.Series(dic))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
#
#
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
#
#
# a    100
# b    200
# c    300
# d    400
# dtype: int64
#
# 1    1000
# 2    2000
# 3    3000
# 4    4000
# dtype: int64
# 0    chetan
# 1      cse2
# 2    prerna
# 3        it
# dtype: str

# %%
tup=('chetan','cse2','prerna','it')
print(pd.Series(tup))
# Out:
# 0    chetan
# 1      cse2
# 2    prerna
# 3        it
# dtype: str

# %% [markdown]
# # DATAFRAME
# ### DATAFRAME IS MADE UP OF MANY SERIES

# %%
data={
    'Names':['chetan','lokendra','abhay','nitin','ronak'],
    'Age': [20,21,21,20,17],
    'City':['sawaimadhopur','orai','bhilai','bhatinda','jodhpur'],
    'Salary':[10,5,8,9,7]
}

label=['A','B','C','D','E']

df=pd.DataFrame(data,index=label)
print(df)
# Out:
#       Names  Age           City  Salary
# A    chetan   20  sawaimadhopur      10
# B  lokendra   21           orai       5
# C     abhay   21         bhilai       8
# D     nitin   20       bhatinda       9
# E     ronak   17        jodhpur       7

# %%
data2=[
    ['chetan',20,'sawaimadhopur',10],
    ['lokendra',21,'orai',5],
    ['abhay',21,'bhilai',8],
    ['nitin',20,'bhatinda',9],
    ['ronak',17,'jodhpur',7]
]

df2=pd.DataFrame(data2,index=label,columns=['Names','Age','city','salary'])
print(df2)


print()

data3=(
    ('chetan',20,'sawaimadhopur',10),
    ('lokendra',21,'orai',5),
    ('abhay',21,'bhilai',8),
    ('nitin',20,'bhatinda',9),
    ('ronak',17,'jodhpur',7)
)

df3=pd.DataFrame(data3,index=label,columns=['Names','Age','city','salary'])
print(df3)
# Out:
#       Names  Age           city  salary
# A    chetan   20  sawaimadhopur      10
# B  lokendra   21           orai       5
# C     abhay   21         bhilai       8
# D     nitin   20       bhatinda       9
# E     ronak   17        jodhpur       7
#
#       Names  Age           city  salary
# A    chetan   20  sawaimadhopur      10
# B  lokendra   21           orai       5
# C     abhay   21         bhilai       8
# D     nitin   20       bhatinda       9
# E     ronak   17        jodhpur       7

# %% [markdown]
# ### slicing and indexing and selecting the data

# %%
print(type(df2))
df2['Names']
# Out:
# <class 'pandas.DataFrame'>
# A      chetan
# B    lokendra
# C       abhay
# D       nitin
# E       ronak
# Name: Names, dtype: str
