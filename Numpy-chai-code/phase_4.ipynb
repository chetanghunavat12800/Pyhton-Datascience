# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mat_load=np.load('mat_rix.npy')
mat_load2=1-mat_load
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(mat_load2)
plt.title("girl image chai")
plt.grid(False)

print()

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(mat_load)
plt.title("girl image chai")
plt.grid(False)

# %%
from PIL import Image

# %%
np_logo=Image.open('numpy_logo.png').convert('RGB')
mat=np.array(np_logo)
np.save('npMatrix',mat)
nplogo_load=np.load('npMatrix.npy')
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(nplogo_load)
plt.title("numpy ka logo ")
plt.grid(False)


print()


black_convert=1-nplogo_load
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(black_convert)
plt.title("numpy ka logo ")
plt.grid(False)

# %%
arr=np.array([[1,2,3],
             [4,5,6]
             ])
print(arr[1,1])
print(arr[1][1])
# Out:
# 5
# 5
